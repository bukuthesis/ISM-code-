# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#PROPYLENE OXIDE ACETONE AND PROPANAL


x = np.array(['Atoms', 'Weight', 'TPSA', 'cLogP', 'Heteroatoms', 'Heavy Atoms', 'SP3 Bonds', 'FSP3', 'Chiral Centers', 'Pubchem'])

y1= [1,5,16,1,14,7,1,3,0,6]
y5 = [5,13,15,2,15,12,5,5,0,13]
y8 = [8,14,14,6,16,13,6,6,0,12]
y12 = [12,10,3,10,8,8,16,16,16,10]
y13 = [13,11,6,13,9,14,13,10,0,9]
y14 = [14,12,4,12,7,11,12,9,0,8]



fig, ax = plt.subplots()
fig.set_size_inches(12,6)


ax.plot(x, y12, label='propylene oxide')
ax.plot(x, y13, label='acetone')
ax.plot(x, y14, label='propanal')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
    
#weight below

x = np.array(['Atoms', 'Weight', 'TPSA', 'cLogP', 'Heteroatoms', 'Heavy Atoms', 'SP3 Bonds', 'FSP3', 'Pubchem', 'Boiling point', 'Melting point', 'Chiral centres'])

y1 = [1,5,10,1,3,2,1,1,4,15,13,1]
y4 = [2,1,8,3,2,1,3,4,1,3,8,1]
y5 = [2,10,10,2,3,3,2,2,11,16,16,1]
y8 = [3,11,8,6,3,3,2,2,10,14,15,1]



fig, ax = plt.subplots()
fig.set_size_inches(12,6)

ax.plot(x, y1, label='Formamide')
ax.plot(x, y4, label='Methylamine')
ax.plot(x, y5, label='Acetamide')
ax.plot(x, y8, label='Acetic acid')


plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
    
#weight below

x = np.array(['Atoms', 'Weight', 'TPSA', 'cLogP', 'Heteroatoms', 'Heavy Atoms', 'SP3 Bonds', 'FSP3', 'Pubchem', 'Melting point', 'Chiral centres'])

z1 = [1,1,2,4,2,1,3,5,1,6,1]
y1 = [1,5,10,1,3,2,1,1,4,13,1]
y4 = [2,1,8,3,2,1,3,4,1,8,1]



fig, ax = plt.subplots()
fig.set_size_inches(12,6)

ax.plot(x, z1, label='Glycine')
ax.plot(x, y1, label='Formamide')
ax.plot(x, y4, label='Methylamine')


plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
    
#Atoms below 9
x = np.array(['Atoms', 'Weight', 'TPSA', 'cLogP', 'Heteroatoms', 'Heavy Atoms', 'SP3 Bonds', 'FSP3', 'Pubchem', 'Boiling point', 'Melting point', 'Chiral centres'])

y1 = [1,5,10,1,3,2,1,1,4,15,13,1]
y2 = [1,3,7,11,2,2,2,2,9,12,12,1]
y3 = [1,2,6,4,2,1,3,4,1,8,6,1]
y4 = [2,1,8,3,2,1,3,4,1,3,8,1]
y5 = [2,10,10,2,3,3,2,2,11,16,16,1]
y6 = [2,7,7,13,2,3,1,1,13,9,10,1]
y7 = [2,4,4,8,2,2,2,2,3,4,3,1]
y8 = [3,11,8,6,3,3,2,2,10,14,15,1]
y9 = [4,6,6,5,2,2,4,4,2,10,4,1]
y10 = [4,8,7,14,2,3,3,3,12,13,9,1]
y11 = [5,6,2,9,2,2,4,4,2,2,2,1]
y12 = [6,9,3,10,2,3,5,4,8,5,5,2]
y13 = [6,9,5,12,2,3,3,3,7,7,7,1]
y14 = [6,9,4,12,2,3,3,3,6,6,11,1]
y15 = [7,12,1,15,1,4,1,1,5,11,14,1]
y16 = [8,13,7,7,2,5,1,1,14,0,0,1]
fig, ax = plt.subplots()
fig.set_size_inches(25,12)

ax.plot(x, y1, label='Formamide')
ax.plot(x, y2, label='Acetonitrile')
ax.plot(x, y3, label='Methanol')
ax.plot(x, y4, label='Methylamine')
ax.plot(x, y5, label='Acetamide')
ax.plot(x, y6, label='Acrylonitrile')
ax.plot(x, y7, label='Acetaldehyde')
ax.plot(x, y8, label='Acetic Acid')
ax.plot(x, y9, label='Ethanol')
ax.plot(x, y10, label='Propionitrile')
ax.plot(x, y11, label='Dimethyl Ether')
ax.plot(x, y12, label='Propylene oxide')
ax.plot(x, y13, label='Acetone')
ax.plot(x, y14, label='Propanal')
ax.plot(x, y15, label='Benzene')
ax.plot(x, y16, label='Cyanodecapentayne')


plt.title("ISM molecule rankings")
plt.xlabel("Property")
plt.ylabel("Molecule rank")

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
    

x = np.array(['Atoms', 'Weight', 'TPSA', 'cLogP', 'Heteroatoms', 'Heavy Atoms', 'SP3 Bonds', 'FSP3', 'Pubchem', 'Melting point', 'Chiral centres'])


z1 = [1,1,2,4,2,1,3,5,1,6,1]
z2 = [2,4,3,5,3,3,1,1,7,11,1]
z3 = [3,2,2,9,2,2,4,6,2,2,8]
z4 = [3,3,4,6,3,3,1,1,8,8,1]
z5 = [4,6,3,8,3,4,2,3,9,10,1]
z6 = [5,5,6,3,3,3,5,7,3,5,3]
z7 = [5,7,9,2,5,4,4,5,5,4,2]
z8 = [6,9,8,7,4,6,4,4,6,7,2]
z9 = [6,8,7,1,5,5,6,9,4,1,4]
z10 = [7,10,5,10,3,7,4,2,10,3,2]
z11 = [8,11,1,11,1,8,7,8,11,2,5]
fig, ax = plt.subplots()
fig.set_size_inches(19,8)

ax.plot(x, z1, label='Glycine')
ax.plot(x, z2, label='Uracil')
ax.plot(x, z3, label='Alanine')
ax.plot(x, z4, label='Cytosine')
ax.plot(x, z5, label='Thymine')
ax.plot(x, z6, label='Threonine')
ax.plot(x, z7, label='Asparagine')
ax.plot(x, z8, label='Histidine')
ax.plot(x, z9, label='Ribose')
ax.plot(x, z10, label='Tryptophan')
ax.plot(x, z11, label='Cholesterol')


plt.title("Biomolecule rankings")
plt.xlabel("Property")
plt.ylabel("Molecule rank")

plt.legend()
plt.show()

# %%
#Glycine vs Asparagine

import matplotlib.pyplot as plt
    

x = np.array(['Atoms', 'Weight', 'TPSA', 'cLogP', 'Heteroatoms', 'Heavy Atoms', 'SP3 Bonds', 'FSP3', 'Pubchem', 'Melting point', 'Chiral centres'])


z1 = [1,1,2,4,2,1,3,5,1,6,1]
z2 = [2,4,3,5,3,3,1,1,7,11,1]
z3 = [3,2,2,9,2,2,4,6,2,2,8]
z4 = [3,3,4,6,3,3,1,1,8,8,1]
z5 = [4,6,3,8,3,4,2,3,9,10,1]
z6 = [5,5,6,3,3,3,5,7,3,5,3]
z7 = [5,7,9,2,5,4,4,5,5,4,2]
z8 = [6,9,8,7,4,6,4,4,6,7,2]
z9 = [6,8,7,1,5,5,6,9,4,1,4]
z10 = [7,10,5,10,3,7,4,2,10,3,2]
z11 = [8,11,1,11,1,8,7,8,11,2,5]
fig, ax = plt.subplots()
fig.set_size_inches(19,8)

ax.plot(x, z1, label='Glycine')
ax.plot(x, z7, label='Asparagine')



plt.title("Biomolecule rankings")
plt.xlabel("Property")
plt.ylabel("Molecule rank")

plt.legend()
plt.show()

# %%
#Comet 67P moelcules 

Acetonitrile 
Acetaldehyde
Methanol 
Dimethyl Ether
Benzene 

import matplotlib.pyplot as plt
    
#Atoms below 9
x = np.array(['Atoms', 'Weight', 'TPSA', 'cLogP', 'Heteroatoms', 'Heavy Atoms', 'SP3 Bonds', 'FSP3', 'Pubchem', 'Boiling point', 'Melting point', 'Chiral centres'])

y1 = [1,5,10,1,3,2,1,1,4,15,13,1]
y2 = [1,3,7,11,2,2,2,2,9,12,12,1]
y3 = [1,2,6,4,2,1,3,4,1,8,6,1]
y4 = [2,1,8,3,2,1,3,4,1,3,8,1]
y5 = [2,10,10,2,3,3,2,2,11,16,16,1]
y6 = [2,7,7,13,2,3,1,1,13,9,10,1]
y7 = [2,4,4,8,2,2,2,2,3,4,3,1]
y8 = [3,11,8,6,3,3,2,2,10,14,15,1]
y9 = [4,6,6,5,2,2,4,4,2,10,4,1]
y10 = [4,8,7,14,2,3,3,3,12,13,9,1]
y11 = [5,6,2,9,2,2,4,4,2,2,2,1]
y12 = [6,9,3,10,2,3,5,4,8,5,5,2]
y13 = [6,9,5,12,2,3,3,3,7,7,7,1]
y14 = [6,9,4,12,2,3,3,3,6,6,11,1]
y15 = [7,12,1,15,1,4,1,1,5,11,14,1]
y16 = [8,13,7,7,2,5,1,1,14,0,0,1]
fig, ax = plt.subplots()
fig.set_size_inches(25,12)

ax.plot(x, y1, label='Formamide')
ax.plot(x, y2, label='Acetonitrile')
ax.plot(x, y3, label='Methanol')
ax.plot(x, y4, label='Methylamine')
ax.plot(x, y5, label='Acetamide')
ax.plot(x, y6, label='Acrylonitrile')
ax.plot(x, y7, label='Acetaldehyde')
ax.plot(x, y8, label='Acetic Acid')
ax.plot(x, y9, label='Ethanol')
ax.plot(x, y10, label='Propionitrile')
ax.plot(x, y11, label='Dimethyl Ether')
ax.plot(x, y12, label='Propylene oxide')
ax.plot(x, y13, label='Acetone')
ax.plot(x, y14, label='Propanal')
ax.plot(x, y15, label='Benzene')
ax.plot(x, y16, label='Cyanodecapentayne')


plt.title("ISM molecule rankings")
plt.xlabel("Property")
plt.ylabel("Molecule rank")

plt.legend()
plt.show()
