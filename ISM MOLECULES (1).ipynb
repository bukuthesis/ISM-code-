# %%
#ISM MOLECULES CODING

import rdkit 
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Descriptors 
from rdkit.Chem import AllChem
from rdkit import DataStructs
from rdkit import Chem
from rdkit.Chem import Crippen
from rdkit.Chem.EnumerateStereoisomers import EnumerateStereoisomers, StereoEnumerationOptions

IPythonConsole.drawOptions.addAtomIndices = True
IPythonConsole.molSize = 400,400

# %%
#Carbon Dioxide 
mol = Chem.MolFromSmiles("C(=O)=O")
mol

# %%
#Methylamine 
mol = Chem.MolFromSmiles("CN")
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)
 
logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('C(C(=O)O)N')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  31.042199159999996
# Topological Surface area =  26.02 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  0
# ClogP =  -0.4251
# Heteroatoms =  1
# Number of Heavy atoms = 2
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 2
# Fraction of SP3 Carbons = 1.0
# Chiral centers =  []
# stereoisomers - NCC(=O)O

# %%
#Propanal

mol = Chem.MolFromSmiles('CCC=O') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('CCC=O')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  58.041864812
# Topological Surface area =  17.07 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  1
# ClogP =  0.5952999999999999
# Heteroatoms =  1
# Number of Heavy atoms = 4
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 2
# Fraction of SP3 Carbons = 0.6666666666666666
# Chiral centers =  []
# stereoisomers - CCC=O

# %%
#Acetamide

mol = Chem.MolFromSmiles('O=C(N)C') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('O=C(N)C')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  59.03711378
# Topological Surface area =  43.09 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  0
# ClogP =  -0.5084000000000002
# Heteroatoms =  2
# Number of Heavy atoms = 4
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 1
# Fraction of SP3 Carbons = 0.5
# Chiral centers =  []
# stereoisomers - CC(N)=O

# %%
#Acetic Acid 

mol = Chem.MolFromSmiles('CC(=O)O') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('CC(=O)O')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  60.021129368000004
# Topological Surface area =  37.3 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  0
# ClogP =  0.09089999999999993
# Heteroatoms =  2
# Number of Heavy atoms = 4
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 1
# Fraction of SP3 Carbons = 0.5
# Chiral centers =  []
# stereoisomers - CC(=O)O

# %%
#Acetone

mol = Chem.MolFromSmiles('CC(=O)C') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('CC(=O)C')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  58.041864812
# Topological Surface area =  17.07 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  0
# ClogP =  0.5952999999999999
# Heteroatoms =  1
# Number of Heavy atoms = 4
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 2
# Fraction of SP3 Carbons = 0.6666666666666666
# Chiral centers =  []
# stereoisomers - CC(C)=O

# %%
#Trans-ethyl-alcohol (Ethanol)

mol = Chem.MolFromSmiles('CCO') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('CCO')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  46.041864812
# Topological Surface area =  20.23 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  0
# ClogP =  -0.0014000000000000123
# Heteroatoms =  1
# Number of Heavy atoms = 3
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 3
# Fraction of SP3 Carbons = 1.0
# Chiral centers =  []
# stereoisomers - CCO

# %%
#Formamide

mol = Chem.MolFromSmiles('C(=O)N') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('C(=O)N')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  45.021463716
# Topological Surface area =  43.09 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  0
# ClogP =  -0.8985000000000001
# Heteroatoms =  2
# Number of Heavy atoms = 3
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 0
# Fraction of SP3 Carbons = 0.0
# Chiral centers =  []
# stereoisomers - NC=O

# %%
#Cyanodecapentayne

mol = Chem.MolFromSmiles('C#CC#CC#CC#CC#CC#N') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('C#CC#CC#CC#CC#CC#N')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  147.010899032
# Topological Surface area =  23.79 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  0
# ClogP =  0.15678
# Heteroatoms =  1
# Number of Heavy atoms = 12
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 0
# Fraction of SP3 Carbons = 0.0
# Chiral centers =  []
# stereoisomers - C#CC#CC#CC#CC#CC#N

# %%
#Propionitrile 

mol = Chem.MolFromSmiles('CCC#N') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('CCC#N')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  55.042199159999996
# Topological Surface area =  23.79 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  0
# ClogP =  0.91998
# Heteroatoms =  1
# Number of Heavy atoms = 4
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 2
# Fraction of SP3 Carbons = 0.6666666666666666
# Chiral centers =  []
# stereoisomers - CCC#N

# %%
#Acrylonitrile 

mol = Chem.MolFromSmiles('C=CC#N') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('C=CC#N')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  53.026549096
# Topological Surface area =  23.79 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  0
# ClogP =  0.6959799999999999
# Heteroatoms =  1
# Number of Heavy atoms = 4
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 0
# Fraction of SP3 Carbons = 0.0
# Chiral centers =  []
# stereoisomers - C=CC#N

# %%
#Acetonitrile (Comet 67-P)

mol = Chem.MolFromSmiles('CC#N') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('CC#N')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  41.026549096
# Topological Surface area =  23.79 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  0
# ClogP =  0.52988
# Heteroatoms =  1
# Number of Heavy atoms = 3
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 1
# Fraction of SP3 Carbons = 0.5
# Chiral centers =  []
# stereoisomers - CC#N

# %%
#Acetaldehyde (Comet 67-P)

mol = Chem.MolFromSmiles('CC=O') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('CC=O')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  44.026214748
# Topological Surface area =  17.07 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  0
# ClogP =  0.2052
# Heteroatoms =  1
# Number of Heavy atoms = 3
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 1
# Fraction of SP3 Carbons = 0.5
# Chiral centers =  []
# stereoisomers - CC=O

# %%
#Methanol

mol = Chem.MolFromSmiles('CO') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('CO')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  32.026214748
# Topological Surface area =  20.23 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  0
# ClogP =  -0.3915
# Heteroatoms =  1
# Number of Heavy atoms = 2
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 2
# Fraction of SP3 Carbons = 1.0
# Chiral centers =  []
# stereoisomers - CO

# %%
#Dimethyl Ether

mol = Chem.MolFromSmiles('COC') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('COC')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  46.041864812
# Topological Surface area =  9.23 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  0
# ClogP =  0.26260000000000006
# Heteroatoms =  1
# Number of Heavy atoms = 3
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 3
# Fraction of SP3 Carbons = 1.0
# Chiral centers =  []
# stereoisomers - COC

# %%
#Benzene 

mol = Chem.MolFromSmiles('C1=CC=CC=C1') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('C1=CC=CC=C1')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  78.046950192
# Topological Surface area =  0.0 Å²
# Number of Hydrogen bond Acceptors =  0
# Number of Hydrogen bond donors =  0
# number of rotatable bonds =  0
# ClogP =  1.6866
# Heteroatoms =  0
# Number of Heavy atoms = 6
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 0
# Fraction of SP3 Carbons = 0.0
# Chiral centers =  []
# stereoisomers - c1ccccc1

# %%
#Propylene oxide  

mol = Chem.MolFromSmiles('CC1CO1') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('CC1CO1')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  58.041864812
# Topological Surface area =  12.53 Å²
# Number of Hydrogen bond Acceptors =  1
# Number of Hydrogen bond donors =  1
# number of rotatable bonds =  0
# ClogP =  0.4051
# Heteroatoms =  1
# Number of Heavy atoms = 4
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 4
# Fraction of SP3 Carbons = 1.0
# Chiral centers =  [(1, '?')]
# stereoisomers - C[C@@H]1CO1
# stereoisomers - C[C@H]1CO1

# %%
#C70 Fullerene (Rugbyballene) 

mol = Chem.MolFromSmiles('C12=C3C4=C5C6=C7C8=C9C%10=C%11C%12=C%13C%10=C%10C8=C5C1=C%10C1=C%13C5=C8C1=C2C1=C3C2=C3C%10=C%13C%14=C3C1=C8C1=C3C5=C%12C5=C8C%11=C%11C9=C7C7=C9C6=C4C2=C2C%10=C4C(=C29)C2=C6C(=C8C8=C9C6=C4C%13=C9C(=C%141)C3=C85)C%11=C27') 
mol

# %%
mw = Descriptors.ExactMolWt(mol)
print ("Molecular wt = ", mw)

TSA = Descriptors.TPSA(mol)
print ("Topological Surface area = ", TSA, "Å²")

hacc = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond Acceptors = ", hacc)

hdon = Descriptors.NumHAcceptors(mol)
print ("Number of Hydrogen bond donors = ", hdon)

rb = Descriptors.NumRotatableBonds(mol)
print ("number of rotatable bonds = ", rb)

logP = Crippen.MolLogP(mol)
print ("ClogP = ", logP)

HA = Descriptors.NumHeteroatoms(mol)
print ("Heteroatoms = ", HA)

hac = Descriptors.HeavyAtomCount(mol)
print ("Number of Heavy atoms =", hac)

ah = Descriptors.NumAromaticHeterocycles(mol)
print ("Number of Aromatic Heterocycles =", ah)

print("SP3 hybridization count =", sum((x.GetHybridization() == Chem.HybridizationType.SP3) for x in mol.GetAtoms()))

SP = Descriptors.FractionCSP3(mol)
print ("Fraction of SP3 Carbons =", SP)

print("Chiral centers = ", Chem.FindMolChiralCenters(mol,force=True,includeUnassigned=True,useLegacyImplementation=False))

m = Chem.MolFromSmiles('C12=C3C4=C5C6=C7C8=C9C%10=C%11C%12=C%13C%10=C%10C8=C5C1=C%10C1=C%13C5=C8C1=C2C1=C3C2=C3C%10=C%13C%14=C3C1=C8C1=C3C5=C%12C5=C8C%11=C%11C9=C7C7=C9C6=C4C2=C2C%10=C4C(=C29)C2=C6C(=C8C8=C9C6=C4C%13=C9C(=C%141)C3=C85)C%11=C27')
isomers = tuple(EnumerateStereoisomers(m))
len(isomers)
16
for smi in sorted(Chem.MolToSmiles(x, isomericSmiles=True) for x in isomers):
    print("stereoisomers -", smi)
# Out:
# Molecular wt =  840.0
# Topological Surface area =  0.0 Å²
# Number of Hydrogen bond Acceptors =  0
# Number of Hydrogen bond donors =  0
# number of rotatable bonds =  0
# ClogP =  20.685000000000016
# Heteroatoms =  0
# Number of Heavy atoms = 70
# Number of Aromatic Heterocycles = 0
# SP3 hybridization count = 0
# Fraction of SP3 Carbons = 0.0
# Chiral centers =  []
# stereoisomers - c12c3c4c5c1c1c6c7c2c2c8c3c3c9c4c4c%10c5c5c1c1c6c6c%11c%12c%13c%14c%15c%16c%17c%14c%14c%18c%13c%11c1c1c5c%10c5c(c%14c%10c%17c%11c%13c%16c%14c%16c%15c%12c%12c%16c(c2c7c%126)c2c8c3c(c%13c%142)c2c9c4c5c%10c%112)c%181

# %%
pip install nbconvert
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
